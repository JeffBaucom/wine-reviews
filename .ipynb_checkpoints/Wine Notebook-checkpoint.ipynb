# %%
# from gensim.models.doc2vec import Doc2Vec, TaggedDocument, Doc2VecVocab, LabeledSentence
from gensim.utils import simple_preprocess
import numpy as np
import pandas as pd
import random
import string

# %%
data = pd.read_csv('raw/raw_wine_data.csv', sep=',', encoding='utf-8')

# %%
varieties = data.variety.unique()

# %%
clean_varieties = []
for i in varieties:
    clean_varieties.append(str(i))

# %%
sorted(clean_varieties)
# Out:
# ['Abouriou',
#  'Agiorgitiko',
#  'Aglianico',
#  'Aidani',
#  'Airen',
#  'Albana',
#  'Albanello',
#  'Albariño',
#  'Albarossa',
#  'Aleatico',
#  'Alfrocheiro',
#  'Alicante',
#  'Alicante Bouschet',
#  'Aligoté',
#  'Alsace white blend',
#  'Altesse',
#  'Alvarelhão',
#  'Alvarinho',
#  'Alvarinho-Chardonnay',
#  'Ansonica',
#  'Antão Vaz',
#  'Apple',
#  'Aragonez',
#  'Aragonês',
#  'Argaman',
#  'Arinto',
#  'Arneis',
#  'Asprinio',
#  'Assyrtico',
#  'Assyrtiko',
#  'Athiri',
#  'Austrian Red Blend',
#  'Austrian white blend',
#  'Auxerrois',
#  'Avesso',
#  'Azal',
#  'Babić',
#  'Babosa Negro',
#  'Bacchus',
#  'Baco Noir',
#  'Baga',
#  'Baga-Touriga Nacional',
#  'Barbera',
#  'Barbera-Nebbiolo',
#  'Bastardo',
#  'Biancale',
#  'Biancolella',
#  'Biancu Gentile',
#  'Bical',
#  'Black Monukka',
#  'Black Muscat',
#  'Blanc du Bois',
#  'Blatina',
#  'Blauburger',
#  'Blauburgunder',
#  'Blauer Portugieser',
#  'Blaufränkisch',
#  'Bobal',
#  'Bobal-Cabernet Sauvignon',
#  'Bombino Bianco',
#  'Bombino Nero',
#  'Bonarda',
#  'Bordeaux-style Red Blend',
#  'Bordeaux-style White Blend',
#  'Bovale',
#  'Boğazkere',
#  'Brachetto',
#  'Braucol',
#  'Bual',
#  'Cabernet',
#  'Cabernet Blend',
#  'Cabernet Franc',
#  'Cabernet Franc-Cabernet Sauvignon',
#  'Cabernet Franc-Carmenère',
#  'Cabernet Franc-Lemberger',
#  'Cabernet Franc-Malbec',
#  'Cabernet Franc-Merlot',
#  'Cabernet Merlot',
#  'Cabernet Moravia',
#  'Cabernet Pfeffer',
#  'Cabernet Sauvignon',
#  'Cabernet Sauvignon Grenache',
#  'Cabernet Sauvignon-Barbera',
#  'Cabernet Sauvignon-Cabernet Franc',
#  'Cabernet Sauvignon-Carmenère',
#  'Cabernet Sauvignon-Malbec',
#  'Cabernet Sauvignon-Merlot',
#  'Cabernet Sauvignon-Merlot-Shiraz',
#  'Cabernet Sauvignon-Sangiovese',
#  'Cabernet Sauvignon-Shiraz',
#  'Cabernet Sauvignon-Syrah',
#  'Cabernet Sauvignon-Tempranillo',
#  'Cabernet-Malbec',
#  'Cabernet-Shiraz',
#  'Cabernet-Syrah',
#  'Canaiolo',
#  'Cannonau',
#  'Caprettone',
#  'Carcajolu',
#  'Carignan',
#  'Carignan-Grenache',
#  'Carignan-Syrah',
#  'Carignane',
#  'Carignano',
#  'Carineña',
#  'Cariñena-Garnacha',
#  'Carmenère',
#  'Carmenère-Cabernet Sauvignon',
#  'Carmenère-Syrah',
#  'Carricante',
#  'Casavecchia',
#  'Castelão',
#  'Catalanesca',
#  'Catarratto',
#  'Cayuga',
#  'Centesimino',
#  'Cerceal',
#  'Cercial',
#  'Cesanese',
#  "Cesanese d'Affile",
#  'Chambourcin',
#  'Champagne Blend',
#  'Chancellor',
#  'Charbono',
#  'Chardonel',
#  'Chardonnay',
#  'Chardonnay Weissburgunder',
#  'Chardonnay-Albariño',
#  'Chardonnay-Pinot Blanc',
#  'Chardonnay-Pinot Gris',
#  'Chardonnay-Riesling',
#  'Chardonnay-Sauvignon',
#  'Chardonnay-Sauvignon Blanc',
#  'Chardonnay-Semillon',
#  'Chardonnay-Viognier',
#  'Chasselas',
#  'Chelois',
#  'Chenin Blanc',
#  'Chenin Blanc-Chardonnay',
#  'Chenin Blanc-Sauvignon Blanc',
#  'Chenin Blanc-Viognier',
#  'Chinuri',
#  'Ciliegiolo',
#  'Cinsault',
#  'Clairette',
#  'Claret',
#  'Cococciola',
#  'Coda di Volpe',
#  'Colombard',
#  'Colombard-Sauvignon Blanc',
#  'Colombard-Ugni Blanc',
#  'Colorino',
#  'Cortese',
#  'Corvina',
#  'Corvina, Rondinella, Molinara',
#  'Counoise',
#  'Códega do Larinho',
#  'Dafni',
#  'Debit',
#  'Diamond',
#  'Dolcetto',
#  'Dornfelder',
#  'Doña Blanca',
#  'Duras',
#  'Durella',
#  'Durif',
#  'Edelzwicker',
#  'Ekigaïna',
#  'Elbling',
#  'Emir',
#  'Encruzado',
#  'Erbaluce',
#  'Espadeiro',
#  'Falanghina',
#  'Favorita',
#  'Fer Servadou',
#  'Fernão Pires',
#  'Feteasca',
#  'Feteasca Neagra',
#  'Feteascǎ Regalǎ',
#  'Fiano',
#  'Folle Blanche',
#  'Forcallà',
#  'Francisa',
#  'Franconia',
#  'Frankovka',
#  'Frappato',
#  'Freisa',
#  'Friulano',
#  'Früburgunder',
#  'Fumé Blanc',
#  'Furmint',
#  'G-S-M',
#  'Gaglioppo',
#  'Gamay',
#  'Gamay Noir',
#  'Gamza',
#  'Garganega',
#  'Garnacha',
#  'Garnacha Blanca',
#  'Garnacha Blend',
#  'Garnacha Tintorera',
#  'Garnacha-Cabernet',
#  'Garnacha-Cariñena',
#  'Garnacha-Monastrell',
#  'Garnacha-Syrah',
#  'Garnacha-Tempranillo',
#  'Gelber Muskateller',
#  'Gelber Traminer',
#  'Gewürztraminer',
#  'Gewürztraminer-Riesling',
#  'Glera',
#  'Godello',
#  'Gouveio',
#  'Graciano',
#  'Gragnano',
#  'Grauburgunder',
#  'Graševina',
#  'Grecanico',
#  'Grechetto',
#  'Greco',
#  'Greco Bianco',
#  'Grenache',
#  'Grenache Blanc',
#  'Grenache Blend',
#  'Grenache Gris',
#  'Grenache Noir',
#  'Grenache-Carignan',
#  'Grenache-Mourvèdre',
#  'Grenache-Shiraz',
#  'Grenache-Syrah',
#  'Grignolino',
#  'Grillo',
#  'Grolleau',
#  'Groppello',
#  'Gros Manseng',
#  'Gros Plant',
#  'Gros and Petit Manseng',
#  'Grüner Veltliner',
#  'Hondarrabi Zuri',
#  'Hárslevelü',
#  'Incrocio Manzoni',
#  'Insolia',
#  'Inzolia',
#  'Irsai Oliver',
#  'Jacquez',
#  'Jacquère',
#  'Jaen',
#  'Jampal',
#  'Johannisberg Riesling',
#  'Kadarka',
#  'Kalecik Karasi',
#  'Kangoun',
#  'Karalahna',
#  'Karasakiz',
#  'Kekfrankos',
#  'Kerner',
#  'Kinali Yapincak',
#  'Kisi',
#  'Kotsifali',
#  'Kuntra',
#  'Lagrein',
#  'Lambrusco',
#  'Lambrusco Grasparossa',
#  'Lambrusco Salamino',
#  'Lambrusco di Sorbara',
#  'Lemberger',
#  'Listán Negro',
#  "Loin de l'Oeil",
#  'Loureiro',
#  'Loureiro-Arinto',
#  'Macabeo',
#  'Macabeo-Chardonnay',
#  'Macabeo-Moscatel',
#  'Madeira Blend',
#  'Madeleine Angevine',
#  'Magliocco',
#  'Malagousia',
#  'Malagouzia',
#  'Malagouzia-Chardonnay',
#  'Malbec',
#  'Malbec Blend',
#  'Malbec-Bonarda',
#  'Malbec-Cabernet',
#  'Malbec-Cabernet Franc',
#  'Malbec-Cabernet Sauvignon',
#  'Malbec-Carménère',
#  'Malbec-Merlot',
#  'Malbec-Petit Verdot',
#  'Malbec-Syrah',
#  'Malbec-Tannat',
#  'Malbec-Tempranillo',
#  'Malvar',
#  'Malvasia',
#  'Malvasia Bianca',
#  'Malvasia Fina',
#  'Malvasia Istriana',
#  'Malvasia Nera',
#  'Malvasia di Candia',
#  'Malvasia-Viura',
#  'Mandilaria',
#  'Mansois',
#  'Mantonico',
#  'Manzoni',
#  'Marawi',
#  'Maria Gomes',
#  'Maria Gomes-Bical',
#  'Marquette',
#  'Marsanne',
#  'Marsanne-Roussanne',
#  'Marsanne-Viognier',
#  'Marselan',
#  'Marzemino',
#  'Mataro',
#  'Maturana',
#  'Mauzac',
#  'Mavrodaphne',
#  'Mavrokalavryta',
#  'Mavrotragano',
#  'Mavroudi',
#  'Mavrud',
#  'Mazuelo',
#  'Melnik',
#  'Melon',
#  'Mencía',
#  'Meritage',
#  'Merlot',
#  'Merlot-Argaman',
#  'Merlot-Cabernet',
#  'Merlot-Cabernet Franc',
#  'Merlot-Cabernet Sauvignon',
#  'Merlot-Grenache',
#  'Merlot-Malbec',
#  'Merlot-Petite Verdot',
#  'Merlot-Shiraz',
#  'Merlot-Syrah',
#  'Merlot-Tannat',
#  'Merseguera-Sauvignon Blanc',
#  'Meseguera',
#  'Misket',
#  'Mission',
#  'Molinara',
#  'Monastrell',
#  'Monastrell-Petit Verdot',
#  'Monastrell-Syrah',
#  'Mondeuse',
#  'Monica',
#  'Montepulciano',
#  'Morava',
#  'Morillon',
#  'Morio Muskat',
#  'Moscadello',
#  'Moscatel',
#  'Moscatel Graúdo',
#  'Moscatel Roxo',
#  'Moscatel de Alejandría',
#  'Moscato',
#  'Moscato Giallo',
#  'Moscato Rosa',
#  'Moscato di Noto',
#  'Moschofilero',
#  'Moschofilero-Chardonnay',
#  'Mourvèdre',
#  'Mourvèdre-Syrah',
#  'Mtsvane',
#  'Muscadel',
#  'Muscadelle',
#  'Muscadine',
#  'Muscat',
#  'Muscat Blanc',
#  'Muscat Blanc à Petits Grains',
#  'Muscat Canelli',
#  'Muscat Hamburg',
#  "Muscat d'Alexandrie",
#  'Muscat of Alexandria',
#  'Muscatel',
#  'Muskat',
#  'Muskat Ottonel',
#  'Muskateller',
#  'Müller-Thurgau',
#  'Narince',
#  'Nascetta',
#  'Nasco',
#  'Nebbiolo',
#  'Negrette',
#  'Negroamaro',
#  'Nerello Cappuccio',
#  'Nerello Mascalese',
#  "Nero d'Avola",
#  'Nero di Troia',
#  'Neuburger',
#  'Nielluciu',
#  'Norton',
#  'Nosiola',
#  'Nuragus',
#  'Ojaleshi',
#  'Okuzgozu',
#  'Ondenc',
#  'Orange Muscat',
#  'Orangetraube',
#  'Other',
#  'Otskhanuri Sapere',
#  'Pallagrello',
#  'Pallagrello Bianco',
#  'Pallagrello Nero',
#  'Palomino',
#  'Pansa Blanca',
#  'Papaskarasi',
#  'Paralleda',
#  'Parraleta',
#  'Passerina',
#  'País',
#  'Pecorino',
#  'Pedro Ximénez',
#  'Perricone',
#  'Petit Courbu',
#  'Petit Manseng',
#  'Petit Meslier',
#  'Petit Verdot',
#  'Petite Sirah',
#  'Petite Verdot',
#  'Picapoll',
#  'Picolit',
#  'Picpoul',
#  'Piedirosso',
#  'Pigato',
#  'Pignoletto',
#  'Pignolo',
#  'Pinot Auxerrois',
#  'Pinot Bianco',
#  'Pinot Blanc',
#  'Pinot Blanc-Chardonnay',
#  'Pinot Blanc-Pinot Noir',
#  'Pinot Blanc-Viognier',
#  'Pinot Grigio',
#  'Pinot Grigio-Sauvignon Blanc',
#  'Pinot Gris',
#  'Pinot Gris-Gewürztraminer',
#  'Pinot Meunier',
#  'Pinot Nero',
#  'Pinot Noir',
#  'Pinot Noir-Gamay',
#  'Pinot Noir-Syrah',
#  'Pinot-Chardonnay',
#  'Pinotage',
#  'Pinotage-Merlot',
#  'Piquepoul Blanc',
#  'Plavac Mali',
#  'Plyto',
#  'Port',
#  'Portuguese Red',
#  'Portuguese Rosé',
#  'Portuguese Sparkling',
#  'Portuguese White',
#  'Portuguiser',
#  'Posip',
#  'Poulsard',
#  'Premsal',
#  'Prieto Picudo',
#  'Primitivo',
#  'Prié Blanc',
#  'Prosecco',
#  'Provence red blend',
#  'Provence white blend',
#  'Prugnolo Gentile',
#  'Prunelard',
#  'Pugnitello',
#  'Rabigato',
#  'Raboso',
#  'Ramisco',
#  'Rara Neagra',
#  'Rebo',
#  'Rebula',
#  'Red Blend',
#  'Refosco',
#  'Rhône-style Red Blend',
#  'Rhône-style White Blend',
#  'Ribolla Gialla',
#  'Rieslaner',
#  'Riesling',
#  'Riesling-Chardonnay',
#  'Rivaner',
#  'Rkatsiteli',
#  'Robola',
#  'Roditis',
#  'Roditis-Moschofilero',
#  'Rolle',
#  'Romorantin',
#  'Rosado',
#  'Rosato',
#  'Roscetto',
#  'Rosenmuskateller',
#  'Rosé',
#  'Roter Traminer',
#  'Roter Veltliner',
#  'Rotgipfler',
#  'Roussanne',
#  'Roussanne-Grenache Blanc',
#  'Roussanne-Marsanne',
#  'Roussanne-Viognier',
#  'Roviello',
#  'Ruché',
#  'Rufete',
#  'Ryzlink Rýnský',
#  'Sacy',
#  'Sagrantino',
#  'Sangiovese',
#  'Sangiovese Cabernet',
#  'Sangiovese Grosso',
#  'Sangiovese-Cabernet Sauvignon',
#  'Sangiovese-Syrah',
#  'Saperavi',
#  'Saperavi-Merlot',
#  'Sauvignon',
#  'Sauvignon Blanc',
#  'Sauvignon Blanc-Assyrtiko',
#  'Sauvignon Blanc-Chardonnay',
#  'Sauvignon Blanc-Chenin Blanc',
#  'Sauvignon Blanc-Sauvignon Gris',
#  'Sauvignon Blanc-Semillon',
#  'Sauvignon Blanc-Verdejo',
#  'Sauvignon Gris',
#  'Sauvignon Musqué',
#  'Sauvignon-Sémillon',
#  'Sauvignonasse',
#  'Savagnin',
#  'Savatiano',
#  'Scheurebe',
#  'Schiava',
#  'Schwartzriesling',
#  'Sciaccerellu',
#  'Semillon-Chardonnay',
#  'Semillon-Sauvignon Blanc',
#  'Sercial',
#  'Seyval Blanc',
#  'Sherry',
#  'Shiraz',
#  'Shiraz-Cabernet',
#  'Shiraz-Cabernet Sauvignon',
#  'Shiraz-Grenache',
#  'Shiraz-Malbec',
#  'Shiraz-Mourvèdre',
#  'Shiraz-Roussanne',
#  'Shiraz-Tempranillo',
#  'Shiraz-Viognier',
#  'Sideritis',
#  'Siegerrebe',
#  'Silvaner',
#  'Silvaner-Traminer',
#  'Siria',
#  'Sirica',
#  'Sousão',
#  'Souzao',
#  'Sparkling Blend',
#  'Spätburgunder',
#  'St. Laurent',
#  'St. Vincent',
#  'Susumaniello',
#  'Sylvaner',
#  'Symphony',
#  'Syrah',
#  'Syrah-Bonarda',
#  'Syrah-Cabernet',
#  'Syrah-Cabernet Franc',
#  'Syrah-Cabernet Sauvignon',
#  'Syrah-Carignan',
#  'Syrah-Grenache',
#  'Syrah-Grenache-Viognier',
#  'Syrah-Malbec',
#  'Syrah-Merlot',
#  'Syrah-Mourvèdre',
#  'Syrah-Petit Verdot',
#  'Syrah-Petite Sirah',
#  'Syrah-Tempranillo',
#  'Syrah-Viognier',
#  'Sämling',
#  'Sémillon',
#  'Tamianka',
#  'Tamjanika',
#  'Tannat',
#  'Tannat-Cabernet',
#  'Tannat-Cabernet Franc',
#  'Tannat-Merlot',
#  'Tannat-Syrah',
#  'Tempranillo',
#  'Tempranillo Blanco',
#  'Tempranillo Blend',
#  'Tempranillo-Cabernet Sauvignon',
#  'Tempranillo-Garnacha',
#  'Tempranillo-Malbec',
#  'Tempranillo-Merlot',
#  'Tempranillo-Shiraz',
#  'Tempranillo-Syrah',
#  'Tempranillo-Tannat',
#  'Teran',
#  'Teroldego',
#  'Teroldego Rotaliano',
#  'Terrantez',
#  'Thrapsathiri',
#  'Timorasso',
#  'Tinta Amarela',
#  'Tinta Barroca',
#  'Tinta Cao',
#  'Tinta Fina',
#  'Tinta Francisca',
#  'Tinta Madeira',
#  'Tinta Miúda',
#  'Tinta Negra Mole',
#  'Tinta Roriz',
#  'Tinta de Toro',
#  'Tinta del Pais',
#  'Tinta del Toro',
#  'Tintilia ',
#  'Tinto Fino',
#  'Tinto Velasco',
#  'Tinto del Pais',
#  'Tocai',
#  'Tocai Friulano',
#  'Tokaji',
#  'Tokay',
#  'Tokay Pinot Gris',
#  'Torbato',
#  'Torontel',
#  'Torrontés',
#  'Touriga',
#  'Touriga Franca',
#  'Touriga Nacional',
#  'Touriga Nacional Blend',
#  'Touriga Nacional-Cabernet Sauvignon',
#  'Trajadura',
#  'Traminer',
#  'Traminette',
#  'Trebbiano',
#  'Trebbiano Spoletino',
#  'Trebbiano di Lugana',
#  'Treixadura',
#  'Trepat',
#  'Trincadeira',
#  'Trollinger',
#  'Trousseau',
#  'Trousseau Gris',
#  'Tsapournakos',
#  'Tsolikouri',
#  'Turbiana',
#  'Tămâioasă Românească',
#  'Ugni Blanc',
#  'Ugni Blanc-Colombard',
#  'Uva di Troia',
#  'Uvalino',
#  'Valdiguié',
#  'Valvin Muscat',
#  'Veltliner',
#  'Verdeca',
#  'Verdejo',
#  'Verdejo-Sauvignon Blanc',
#  'Verdejo-Viura',
#  'Verdelho',
#  'Verdicchio',
#  'Verdil',
#  'Verdosilla',
#  'Verduzzo',
#  'Verduzzo Friulano ',
#  'Vermentino',
#  'Vermentino Nero',
#  'Vernaccia',
#  'Vespaiolo',
#  'Vespolina',
#  'Vidadillo',
#  'Vidal',
#  'Vidal Blanc',
#  'Vignoles',
#  'Vilana',
#  'Vinhão',
#  'Viognier',
#  'Viognier-Chardonnay',
#  'Viognier-Gewürztraminer',
#  'Viognier-Grenache Blanc',
#  'Viognier-Marsanne',
#  'Viognier-Roussanne',
#  'Viognier-Valdiguié',
#  'Viosinho',
#  'Vital',
#  'Vitovska',
#  'Viura',
#  'Viura-Chardonnay',
#  'Viura-Verdejo',
#  'Vranac',
#  'Vranec',
#  'Weissburgunder',
#  'Welschriesling',
#  'White Blend',
#  'White Port',
#  'White Riesling',
#  'Xarel-lo',
#  'Xinisteri',
#  'Xinomavro',
#  'Xynisteri',
#  'Yapincak',
#  'Zelen',
#  'Zibibbo',
#  'Zierfandler',
#  'Zierfandler-Rotgipfler',
#  'Zinfandel',
#  'Zlahtina',
#  'Zweigelt',
#  'nan',
#  'Çalkarası',
#  'Žilavka']

# %%
variety_dict = {}
print(random.choice(clean_varieties))
# Out:
# Kuntra

# %%
leftovers = []
for i in clean_varieties:
    lower_cased = i.lower()
    if 'red' in lower_cased or 'noir' in lower_cased:
        variety_dict[i] = 'red'
    elif 'white' in lower_cased or 'blanc' in lower_cased or "gewürztraminer" in lower_cased:
        variety_dict[i] = 'white'
    elif 'rosé' in lower_cased:
        variety_dict[i] = 'rosé'
    elif 'sparkling' in lower_cased:
        variety_dict[i] = 'sparkling'
    elif 'cabernet' in lower_cased or 'malbec' in lower_cased:
        variety_dict[i] = 'red'
    else:
        leftovers.append(i)

# %%
len(leftovers)
# Out:
# 579

# %%
variety_dict
# Out:
# {'Abouriou': 'red',
#  'Agiorgitiko': 'red',
#  'Aglianico': 'red',
#  'Aidani': 'red',
#  'Airen': 'red',
#  'Albana': 'red',
#  'Albanello': 'red',
#  'Albariño': 'red',
#  'Albarossa': 'red',
#  'Aleatico': 'red',
#  'Alfrocheiro': 'red',
#  'Alicante': 'red',
#  'Alicante Bouschet': 'red',
#  'Aligoté': 'red',
#  'Alsace white blend': 'white',
#  'Altesse': 'red',
#  'Alvarelhão': 'red',
#  'Alvarinho': 'red',
#  'Alvarinho-Chardonnay': 'red',
#  'Ansonica': 'red',
#  'Antão Vaz': 'red',
#  'Apple': 'red',
#  'Aragonez': 'red',
#  'Aragonês': 'red',
#  'Argaman': 'red',
#  'Arinto': 'red',
#  'Arneis': 'red',
#  'Asprinio': 'red',
#  'Assyrtico': 'red',
#  'Assyrtiko': 'red',
#  'Athiri': 'red',
#  'Austrian Red Blend': 'red',
#  'Austrian white blend': 'white',
#  'Auxerrois': 'red',
#  'Avesso': 'red',
#  'Azal': 'red',
#  'Babić': 'red',
#  'Babosa Negro': 'red',
#  'Bacchus': 'red',
#  'Baco Noir': 'red',
#  'Baga': 'red',
#  'Baga-Touriga Nacional': 'red',
#  'Barbera': 'red',
#  'Barbera-Nebbiolo': 'red',
#  'Bastardo': 'red',
#  'Biancale': 'red',
#  'Biancolella': 'red',
#  'Biancu Gentile': 'red',
#  'Bical': 'red',
#  'Black Monukka': 'red',
#  'Black Muscat': 'red',
#  'Blanc du Bois': 'white',
#  'Blatina': 'red',
#  'Blauburger': 'red',
#  'Blauburgunder': 'red',
#  'Blauer Portugieser': 'red',
#  'Blaufränkisch': 'red',
#  'Bobal': 'red',
#  'Bobal-Cabernet Sauvignon': 'red',
#  'Bombino Bianco': 'red',
#  'Bombino Nero': 'red',
#  'Bonarda': 'red',
#  'Bordeaux-style Red Blend': 'red',
#  'Bordeaux-style White Blend': 'white',
#  'Bovale': 'red',
#  'Boğazkere': 'red',
#  'Brachetto': 'red',
#  'Braucol': 'red',
#  'Bual': 'red',
#  'Cabernet': 'red',
#  'Cabernet Blend': 'red',
#  'Cabernet Franc': 'red',
#  'Cabernet Franc-Cabernet Sauvignon': 'red',
#  'Cabernet Franc-Carmenère': 'red',
#  'Cabernet Franc-Lemberger': 'red',
#  'Cabernet Franc-Malbec': 'red',
#  'Cabernet Franc-Merlot': 'red',
#  'Cabernet Merlot': 'red',
#  'Cabernet Moravia': 'red',
#  'Cabernet Pfeffer': 'red',
#  'Cabernet Sauvignon': 'red',
#  'Cabernet Sauvignon Grenache': 'red',
#  'Cabernet Sauvignon-Barbera': 'red',
#  'Cabernet Sauvignon-Cabernet Franc': 'red',
#  'Cabernet Sauvignon-Carmenère': 'red',
#  'Cabernet Sauvignon-Malbec': 'red',
#  'Cabernet Sauvignon-Merlot': 'red',
#  'Cabernet Sauvignon-Merlot-Shiraz': 'red',
#  'Cabernet Sauvignon-Sangiovese': 'red',
#  'Cabernet Sauvignon-Shiraz': 'red',
#  'Cabernet Sauvignon-Syrah': 'red',
#  'Cabernet Sauvignon-Tempranillo': 'red',
#  'Cabernet-Malbec': 'red',
#  'Cabernet-Shiraz': 'red',
#  'Cabernet-Syrah': 'red',
#  'Canaiolo': 'red',
#  'Cannonau': 'red',
#  'Caprettone': 'red',
#  'Carcajolu': 'red',
#  'Carignan': 'red',
#  'Carignan-Grenache': 'red',
#  'Carignan-Syrah': 'red',
#  'Carignane': 'red',
#  'Carignano': 'red',
#  'Carineña': 'red',
#  'Cariñena-Garnacha': 'red',
#  'Carmenère': 'red',
#  'Carmenère-Cabernet Sauvignon': 'red',
#  'Carmenère-Syrah': 'red',
#  'Carricante': 'red',
#  'Casavecchia': 'red',
#  'Castelão': 'red',
#  'Catalanesca': 'red',
#  'Catarratto': 'red',
#  'Cayuga': 'red',
#  'Centesimino': 'red',
#  'Cerceal': 'red',
#  'Cercial': 'red',
#  'Cesanese': 'red',
#  "Cesanese d'Affile": 'red',
#  'Chambourcin': 'red',
#  'Champagne Blend': 'red',
#  'Chancellor': 'red',
#  'Charbono': 'red',
#  'Chardonel': 'red',
#  'Chardonnay': 'red',
#  'Chardonnay Weissburgunder': 'red',
#  'Chardonnay-Albariño': 'red',
#  'Chardonnay-Pinot Blanc': 'white',
#  'Chardonnay-Pinot Gris': 'red',
#  'Chardonnay-Riesling': 'red',
#  'Chardonnay-Sauvignon': 'red',
#  'Chardonnay-Sauvignon Blanc': 'white',
#  'Chardonnay-Semillon': 'red',
#  'Chardonnay-Viognier': 'red',
#  'Chasselas': 'red',
#  'Chelois': 'red',
#  'Chenin Blanc': 'white',
#  'Chenin Blanc-Chardonnay': 'white',
#  'Chenin Blanc-Sauvignon Blanc': 'white',
#  'Chenin Blanc-Viognier': 'white',
#  'Chinuri': 'red',
#  'Ciliegiolo': 'red',
#  'Cinsault': 'red',
#  'Clairette': 'red',
#  'Claret': 'red',
#  'Cococciola': 'red',
#  'Coda di Volpe': 'red',
#  'Colombard': 'red',
#  'Colombard-Sauvignon Blanc': 'white',
#  'Colombard-Ugni Blanc': 'white',
#  'Colorino': 'red',
#  'Cortese': 'red',
#  'Corvina': 'red',
#  'Corvina, Rondinella, Molinara': 'red',
#  'Counoise': 'red',
#  'Códega do Larinho': 'red',
#  'Dafni': 'red',
#  'Debit': 'red',
#  'Diamond': 'red',
#  'Dolcetto': 'red',
#  'Dornfelder': 'red',
#  'Doña Blanca': 'white',
#  'Duras': 'red',
#  'Durella': 'red',
#  'Durif': 'red',
#  'Edelzwicker': 'red',
#  'Ekigaïna': 'red',
#  'Elbling': 'red',
#  'Emir': 'red',
#  'Encruzado': 'red',
#  'Erbaluce': 'red',
#  'Espadeiro': 'red',
#  'Falanghina': 'red',
#  'Favorita': 'red',
#  'Fer Servadou': 'red',
#  'Fernão Pires': 'red',
#  'Feteasca': 'red',
#  'Feteasca Neagra': 'red',
#  'Feteascǎ Regalǎ': 'red',
#  'Fiano': 'red',
#  'Folle Blanche': 'white',
#  'Forcallà': 'red',
#  'Francisa': 'red',
#  'Franconia': 'red',
#  'Frankovka': 'red',
#  'Frappato': 'red',
#  'Freisa': 'red',
#  'Friulano': 'red',
#  'Früburgunder': 'red',
#  'Fumé Blanc': 'white',
#  'Furmint': 'red',
#  'G-S-M': 'red',
#  'Gaglioppo': 'red',
#  'Gamay': 'red',
#  'Gamay Noir': 'red',
#  'Gamza': 'red',
#  'Garganega': 'red',
#  'Garnacha': 'red',
#  'Garnacha Blanca': 'white',
#  'Garnacha Blend': 'red',
#  'Garnacha Tintorera': 'red',
#  'Garnacha-Cabernet': 'red',
#  'Garnacha-Cariñena': 'red',
#  'Garnacha-Monastrell': 'red',
#  'Garnacha-Syrah': 'red',
#  'Garnacha-Tempranillo': 'red',
#  'Gelber Muskateller': 'red',
#  'Gelber Traminer': 'red',
#  'Gewürztraminer': 'white',
#  'Gewürztraminer-Riesling': 'white',
#  'Glera': 'red',
#  'Godello': 'red',
#  'Gouveio': 'red',
#  'Graciano': 'red',
#  'Gragnano': 'red',
#  'Grauburgunder': 'red',
#  'Graševina': 'red',
#  'Grecanico': 'red',
#  'Grechetto': 'red',
#  'Greco': 'red',
#  'Greco Bianco': 'red',
#  'Grenache': 'red',
#  'Grenache Blanc': 'white',
#  'Grenache Blend': 'red',
#  'Grenache Gris': 'red',
#  'Grenache Noir': 'red',
#  'Grenache-Carignan': 'red',
#  'Grenache-Mourvèdre': 'red',
#  'Grenache-Shiraz': 'red',
#  'Grenache-Syrah': 'red',
#  'Grignolino': 'red',
#  'Grillo': 'red',
#  'Grolleau': 'red',
#  'Groppello': 'red',
#  'Gros Manseng': 'red',
#  'Gros Plant': 'red',
#  'Gros and Petit Manseng': 'red',
#  'Grüner Veltliner': 'red',
#  'Hondarrabi Zuri': 'red',
#  'Hárslevelü': 'red',
#  'Incrocio Manzoni': 'red',
#  'Insolia': 'red',
#  'Inzolia': 'red',
#  'Irsai Oliver': 'red',
#  'Jacquez': 'red',
#  'Jacquère': 'red',
#  'Jaen': 'red',
#  'Jampal': 'red',
#  'Johannisberg Riesling': 'red',
#  'Kadarka': 'red',
#  'Kalecik Karasi': 'red',
#  'Kangoun': 'red',
#  'Karalahna': 'red',
#  'Karasakiz': 'red',
#  'Kekfrankos': 'red',
#  'Kerner': 'red',
#  'Kinali Yapincak': 'red',
#  'Kisi': 'red',
#  'Kotsifali': 'red',
#  'Kuntra': 'red',
#  'Lagrein': 'red',
#  'Lambrusco': 'red',
#  'Lambrusco Grasparossa': 'red',
#  'Lambrusco Salamino': 'red',
#  'Lambrusco di Sorbara': 'red',
#  'Lemberger': 'red',
#  'Listán Negro': 'red',
#  "Loin de l'Oeil": 'red',
#  'Loureiro': 'red',
#  'Loureiro-Arinto': 'red',
#  'Macabeo': 'red',
#  'Macabeo-Chardonnay': 'red',
#  'Macabeo-Moscatel': 'red',
#  'Madeira Blend': 'red',
#  'Madeleine Angevine': 'red',
#  'Magliocco': 'red',
#  'Malagousia': 'red',
#  'Malagouzia': 'red',
#  'Malagouzia-Chardonnay': 'red',
#  'Malbec': 'red',
#  'Malbec Blend': 'red',
#  'Malbec-Bonarda': 'red',
#  'Malbec-Cabernet': 'red',
#  'Malbec-Cabernet Franc': 'red',
#  'Malbec-Cabernet Sauvignon': 'red',
#  'Malbec-Carménère': 'red',
#  'Malbec-Merlot': 'red',
#  'Malbec-Petit Verdot': 'red',
#  'Malbec-Syrah': 'red',
#  'Malbec-Tannat': 'red',
#  'Malbec-Tempranillo': 'red',
#  'Malvar': 'red',
#  'Malvasia': 'red',
#  'Malvasia Bianca': 'red',
#  'Malvasia Fina': 'red',
#  'Malvasia Istriana': 'red',
#  'Malvasia Nera': 'red',
#  'Malvasia di Candia': 'red',
#  'Malvasia-Viura': 'red',
#  'Mandilaria': 'red',
#  'Mansois': 'red',
#  'Mantonico': 'red',
#  'Manzoni': 'red',
#  'Marawi': 'red',
#  'Maria Gomes': 'red',
#  'Maria Gomes-Bical': 'red',
#  'Marquette': 'red',
#  'Marsanne': 'red',
#  'Marsanne-Roussanne': 'red',
#  'Marsanne-Viognier': 'red',
#  'Marselan': 'red',
#  'Marzemino': 'red',
#  'Mataro': 'red',
#  'Maturana': 'red',
#  'Mauzac': 'red',
#  'Mavrodaphne': 'red',
#  'Mavrokalavryta': 'red',
#  'Mavrotragano': 'red',
#  'Mavroudi': 'red',
#  'Mavrud': 'red',
#  'Mazuelo': 'red',
#  'Melnik': 'red',
#  'Melon': 'red',
#  'Mencía': 'red',
#  'Meritage': 'red',
#  'Merlot': 'red',
#  'Merlot-Argaman': 'red',
#  'Merlot-Cabernet': 'red',
#  'Merlot-Cabernet Franc': 'red',
#  'Merlot-Cabernet Sauvignon': 'red',
#  'Merlot-Grenache': 'red',
#  'Merlot-Malbec': 'red',
#  'Merlot-Petite Verdot': 'red',
#  'Merlot-Shiraz': 'red',
#  'Merlot-Syrah': 'red',
#  'Merlot-Tannat': 'red',
#  'Merseguera-Sauvignon Blanc': 'white',
#  'Meseguera': 'red',
#  'Misket': 'red',
#  'Mission': 'red',
#  'Molinara': 'red',
#  'Monastrell': 'red',
#  'Monastrell-Petit Verdot': 'red',
#  'Monastrell-Syrah': 'red',
#  'Mondeuse': 'red',
#  'Monica': 'red',
#  'Montepulciano': 'red',
#  'Morava': 'red',
#  'Morillon': 'red',
#  'Morio Muskat': 'red',
#  'Moscadello': 'red',
#  'Moscatel': 'red',
#  'Moscatel Graúdo': 'red',
#  'Moscatel Roxo': 'red',
#  'Moscatel de Alejandría': 'red',
#  'Moscato': 'red',
#  'Moscato Giallo': 'red',
#  'Moscato Rosa': 'red',
#  'Moscato di Noto': 'red',
#  'Moschofilero': 'red',
#  'Moschofilero-Chardonnay': 'red',
#  'Mourvèdre': 'red',
#  'Mourvèdre-Syrah': 'red',
#  'Mtsvane': 'red',
#  'Muscadel': 'red',
#  'Muscadelle': 'red',
#  'Muscadine': 'red',
#  'Muscat': 'red',
#  'Muscat Blanc': 'white',
#  'Muscat Blanc à Petits Grains': 'white',
#  'Muscat Canelli': 'red',
#  'Muscat Hamburg': 'red',
#  "Muscat d'Alexandrie": 'red',
#  'Muscat of Alexandria': 'red',
#  'Muscatel': 'red',
#  'Muskat': 'red',
#  'Muskat Ottonel': 'red',
#  'Muskateller': 'red',
#  'Müller-Thurgau': 'red',
#  'Narince': 'red',
#  'Nascetta': 'red',
#  'Nasco': 'red',
#  'Nebbiolo': 'red',
#  'Negrette': 'red',
#  'Negroamaro': 'red',
#  'Nerello Cappuccio': 'red',
#  'Nerello Mascalese': 'red',
#  "Nero d'Avola": 'red',
#  'Nero di Troia': 'red',
#  'Neuburger': 'red',
#  'Nielluciu': 'red',
#  'Norton': 'red',
#  'Nosiola': 'red',
#  'Nuragus': 'red',
#  'Ojaleshi': 'red',
#  'Okuzgozu': 'red',
#  'Ondenc': 'red',
#  'Orange Muscat': 'red',
#  'Orangetraube': 'red',
#  'Other': 'red',
#  'Otskhanuri Sapere': 'red',
#  'Pallagrello': 'red',
#  'Pallagrello Bianco': 'red',
#  'Pallagrello Nero': 'red',
#  'Palomino': 'red',
#  'Pansa Blanca': 'white',
#  'Papaskarasi': 'red',
#  'Paralleda': 'red',
#  'Parraleta': 'red',
#  'Passerina': 'red',
#  'País': 'red',
#  'Pecorino': 'red',
#  'Pedro Ximénez': 'red',
#  'Perricone': 'red',
#  'Petit Courbu': 'red',
#  'Petit Manseng': 'red',
#  'Petit Meslier': 'red',
#  'Petit Verdot': 'red',
#  'Petite Sirah': 'red',
#  'Petite Verdot': 'red',
#  'Picapoll': 'red',
#  'Picolit': 'red',
#  'Picpoul': 'red',
#  'Piedirosso': 'red',
#  'Pigato': 'red',
#  'Pignoletto': 'red',
#  'Pignolo': 'red',
#  'Pinot Auxerrois': 'red',
#  'Pinot Bianco': 'red',
#  'Pinot Blanc': 'white',
#  'Pinot Blanc-Chardonnay': 'white',
#  'Pinot Blanc-Pinot Noir': 'red',
#  'Pinot Blanc-Viognier': 'white',
#  'Pinot Grigio': 'red',
#  'Pinot Grigio-Sauvignon Blanc': 'white',
#  'Pinot Gris': 'red',
#  'Pinot Gris-Gewürztraminer': 'white',
#  'Pinot Meunier': 'red',
#  'Pinot Nero': 'red',
#  'Pinot Noir': 'red',
#  'Pinot Noir-Gamay': 'red',
#  'Pinot Noir-Syrah': 'red',
#  'Pinot-Chardonnay': 'red',
#  'Pinotage': 'red',
#  'Pinotage-Merlot': 'red',
#  'Piquepoul Blanc': 'white',
#  'Plavac Mali': 'red',
#  'Plyto': 'red',
#  'Port': 'red',
#  'Portuguese Red': 'red',
#  'Portuguese Rosé': 'rosé',
#  'Portuguese Sparkling': 'sparkling',
#  'Portuguese White': 'white',
#  'Portuguiser': 'red',
#  'Posip': 'red',
#  'Poulsard': 'red',
#  'Premsal': 'red',
#  'Prieto Picudo': 'red',
#  'Primitivo': 'red',
#  'Prié Blanc': 'white',
#  'Prosecco': 'red',
#  'Provence red blend': 'red',
#  'Provence white blend': 'white',
#  'Prugnolo Gentile': 'red',
#  'Prunelard': 'red',
#  'Pugnitello': 'red',
#  'Rabigato': 'red',
#  'Raboso': 'red',
#  'Ramisco': 'red',
#  'Rara Neagra': 'red',
#  'Rebo': 'red',
#  'Rebula': 'red',
#  'Red Blend': 'red',
#  'Refosco': 'red',
#  'Rhône-style Red Blend': 'red',
#  'Rhône-style White Blend': 'white',
#  'Ribolla Gialla': 'red',
#  'Rieslaner': 'red',
#  'Riesling': 'red',
#  'Riesling-Chardonnay': 'red',
#  'Rivaner': 'red',
#  'Rkatsiteli': 'red',
#  'Robola': 'red',
#  'Roditis': 'red',
#  'Roditis-Moschofilero': 'red',
#  'Rolle': 'red',
#  'Romorantin': 'red',
#  'Rosado': 'red',
#  'Rosato': 'red',
#  'Roscetto': 'red',
#  'Rosenmuskateller': 'red',
#  'Rosé': 'rosé',
#  'Roter Traminer': 'red',
#  'Roter Veltliner': 'red',
#  'Rotgipfler': 'red',
#  'Roussanne': 'red',
#  'Roussanne-Grenache Blanc': 'white',
#  'Roussanne-Marsanne': 'red',
#  'Roussanne-Viognier': 'red',
#  'Roviello': 'red',
#  'Ruché': 'red',
#  'Rufete': 'red',
#  'Ryzlink Rýnský': 'red',
#  'Sacy': 'red',
#  'Sagrantino': 'red',
#  'Sangiovese': 'red',
#  'Sangiovese Cabernet': 'red',
#  'Sangiovese Grosso': 'red',
#  'Sangiovese-Cabernet Sauvignon': 'red',
#  'Sangiovese-Syrah': 'red',
#  'Saperavi': 'red',
#  'Saperavi-Merlot': 'red',
#  'Sauvignon': 'red',
#  'Sauvignon Blanc': 'white',
#  'Sauvignon Blanc-Assyrtiko': 'white',
#  'Sauvignon Blanc-Chardonnay': 'white',
#  'Sauvignon Blanc-Chenin Blanc': 'white',
#  'Sauvignon Blanc-Sauvignon Gris': 'white',
#  'Sauvignon Blanc-Semillon': 'white',
#  'Sauvignon Blanc-Verdejo': 'white',
#  'Sauvignon Gris': 'red',
#  'Sauvignon Musqué': 'red',
#  'Sauvignon-Sémillon': 'red',
#  'Sauvignonasse': 'red',
#  'Savagnin': 'red',
#  'Savatiano': 'red',
#  'Scheurebe': 'red',
#  'Schiava': 'red',
#  'Schwartzriesling': 'red',
#  'Sciaccerellu': 'red',
#  'Semillon-Chardonnay': 'red',
#  'Semillon-Sauvignon Blanc': 'white',
#  'Sercial': 'red',
#  'Seyval Blanc': 'white',
#  'Sherry': 'red',
#  'Shiraz': 'red',
#  'Shiraz-Cabernet': 'red',
#  'Shiraz-Cabernet Sauvignon': 'red',
#  'Shiraz-Grenache': 'red',
#  'Shiraz-Malbec': 'red',
#  'Shiraz-Mourvèdre': 'red',
#  'Shiraz-Roussanne': 'red',
#  'Shiraz-Tempranillo': 'red',
#  'Shiraz-Viognier': 'red',
#  'Sideritis': 'red',
#  'Siegerrebe': 'red',
#  'Silvaner': 'red',
#  'Silvaner-Traminer': 'red',
#  'Siria': 'red',
#  'Sirica': 'red',
#  'Sousão': 'red',
#  'Souzao': 'red',
#  'Sparkling Blend': 'sparkling',
#  'Spätburgunder': 'red',
#  'St. Laurent': 'red',
#  'St. Vincent': 'red',
#  'Susumaniello': 'red',
#  'Sylvaner': 'red',
#  'Symphony': 'red',
#  'Syrah': 'red',
#  'Syrah-Bonarda': 'red',
#  'Syrah-Cabernet': 'red',
#  'Syrah-Cabernet Franc': 'red',
#  'Syrah-Cabernet Sauvignon': 'red',
#  'Syrah-Carignan': 'red',
#  'Syrah-Grenache': 'red',
#  'Syrah-Grenache-Viognier': 'red',
#  'Syrah-Malbec': 'red',
#  'Syrah-Merlot': 'red',
#  'Syrah-Mourvèdre': 'red',
#  'Syrah-Petit Verdot': 'red',
#  'Syrah-Petite Sirah': 'red',
#  'Syrah-Tempranillo': 'red',
#  'Syrah-Viognier': 'red',
#  'Sämling': 'red',
#  'Sémillon': 'red',
#  'Tamianka': 'red',
#  'Tamjanika': 'red',
#  'Tannat': 'red',
#  'Tannat-Cabernet': 'red',
#  'Tannat-Cabernet Franc': 'red',
#  'Tannat-Merlot': 'red',
#  'Tannat-Syrah': 'red',
#  'Tempranillo': 'red',
#  'Tempranillo Blanco': 'white',
#  'Tempranillo Blend': 'red',
#  'Tempranillo-Cabernet Sauvignon': 'red',
#  'Tempranillo-Garnacha': 'red',
#  'Tempranillo-Malbec': 'red',
#  'Tempranillo-Merlot': 'red',
#  'Tempranillo-Shiraz': 'red',
#  'Tempranillo-Syrah': 'red',
#  'Tempranillo-Tannat': 'red',
#  'Teran': 'red',
#  'Teroldego': 'red',
#  'Teroldego Rotaliano': 'red',
#  'Terrantez': 'red',
#  'Thrapsathiri': 'red',
#  'Timorasso': 'red',
#  'Tinta Amarela': 'red',
#  'Tinta Barroca': 'red',
#  'Tinta Cao': 'red',
#  'Tinta Fina': 'red',
#  'Tinta Francisca': 'red',
#  'Tinta Madeira': 'red',
#  'Tinta Miúda': 'red',
#  'Tinta Negra Mole': 'red',
#  'Tinta Roriz': 'red',
#  'Tinta de Toro': 'red',
#  'Tinta del Pais': 'red',
#  'Tinta del Toro': 'red',
#  'Tintilia ': 'red',
#  'Tinto Fino': 'red',
#  'Tinto Velasco': 'red',
#  'Tinto del Pais': 'red',
#  'Tocai': 'red',
#  'Tocai Friulano': 'red',
#  'Tokaji': 'red',
#  'Tokay': 'red',
#  'Tokay Pinot Gris': 'red',
#  'Torbato': 'red',
#  'Torontel': 'red',
#  'Torrontés': 'red',
#  'Touriga': 'red',
#  'Touriga Franca': 'red',
#  'Touriga Nacional': 'red',
#  'Touriga Nacional Blend': 'red',
#  'Touriga Nacional-Cabernet Sauvignon': 'red',
#  'Trajadura': 'red',
#  'Traminer': 'red',
#  'Traminette': 'red',
#  'Trebbiano': 'red',
#  'Trebbiano Spoletino': 'red',
#  'Trebbiano di Lugana': 'red',
#  'Treixadura': 'red',
#  'Trepat': 'red',
#  'Trincadeira': 'red',
#  'Trollinger': 'red',
#  'Trousseau': 'red',
#  'Trousseau Gris': 'red',
#  'Tsapournakos': 'red',
#  'Tsolikouri': 'red',
#  'Turbiana': 'red',
#  'Tămâioasă Românească': 'red',
#  'Ugni Blanc': 'white',
#  'Ugni Blanc-Colombard': 'white',
#  'Uva di Troia': 'red',
#  'Uvalino': 'red',
#  'Valdiguié': 'red',
#  'Valvin Muscat': 'red',
#  'Veltliner': 'red',
#  'Verdeca': 'red',
#  'Verdejo': 'red',
#  'Verdejo-Sauvignon Blanc': 'white',
#  'Verdejo-Viura': 'red',
#  'Verdelho': 'red',
#  'Verdicchio': 'red',
#  'Verdil': 'red',
#  'Verdosilla': 'red',
#  'Verduzzo': 'red',
#  'Verduzzo Friulano ': 'red',
#  'Vermentino': 'red',
#  'Vermentino Nero': 'red',
#  'Vernaccia': 'red',
#  'Vespaiolo': 'red',
#  'Vespolina': 'red',
#  'Vidadillo': 'red',
#  'Vidal': 'red',
#  'Vidal Blanc': 'white',
#  'Vignoles': 'red',
#  'Vilana': 'red',
#  'Vinhão': 'red',
#  'Viognier': 'red',
#  'Viognier-Chardonnay': 'red',
#  'Viognier-Gewürztraminer': 'white',
#  'Viognier-Grenache Blanc': 'white',
#  'Viognier-Marsanne': 'red',
#  'Viognier-Roussanne': 'red',
#  'Viognier-Valdiguié': 'red',
#  'Viosinho': 'red',
#  'Vital': 'red',
#  'Vitovska': 'red',
#  'Viura': 'red',
#  'Viura-Chardonnay': 'red',
#  'Viura-Verdejo': 'red',
#  'Vranac': 'red',
#  'Vranec': 'red',
#  'Weissburgunder': 'red',
#  'Welschriesling': 'red',
#  'White Blend': 'white',
#  'White Port': 'white',
#  'White Riesling': 'white',
#  'Xarel-lo': 'red',
#  'Xinisteri': 'red',
#  'Xinomavro': 'red',
#  'Xynisteri': 'red',
#  'Yapincak': 'red',
#  'Zelen': 'red',
#  'Zibibbo': 'red',
#  'Zierfandler': 'red',
#  'Zierfandler-Rotgipfler': 'red',
#  'Zinfandel': 'red',
#  'Zlahtina': 'red',
#  'Zweigelt': 'red',
#  'nan': 'red',
#  'Çalkarası': 'red',
#  'Žilavka': 'red'}

# %%
sorted(leftovers)
# Out:
# ['Abouriou',
#  'Agiorgitiko',
#  'Aglianico',
#  'Aidani',
#  'Airen',
#  'Albana',
#  'Albanello',
#  'Albariño',
#  'Albarossa',
#  'Aleatico',
#  'Alfrocheiro',
#  'Alicante',
#  'Alicante Bouschet',
#  'Aligoté',
#  'Altesse',
#  'Alvarelhão',
#  'Alvarinho',
#  'Alvarinho-Chardonnay',
#  'Ansonica',
#  'Antão Vaz',
#  'Apple',
#  'Aragonez',
#  'Aragonês',
#  'Argaman',
#  'Arinto',
#  'Arneis',
#  'Asprinio',
#  'Assyrtico',
#  'Assyrtiko',
#  'Athiri',
#  'Auxerrois',
#  'Avesso',
#  'Azal',
#  'Babić',
#  'Babosa Negro',
#  'Bacchus',
#  'Baga',
#  'Baga-Touriga Nacional',
#  'Barbera',
#  'Barbera-Nebbiolo',
#  'Bastardo',
#  'Biancale',
#  'Biancolella',
#  'Biancu Gentile',
#  'Bical',
#  'Black Monukka',
#  'Black Muscat',
#  'Blatina',
#  'Blauburger',
#  'Blauburgunder',
#  'Blauer Portugieser',
#  'Blaufränkisch',
#  'Bobal',
#  'Bombino Bianco',
#  'Bombino Nero',
#  'Bonarda',
#  'Bovale',
#  'Boğazkere',
#  'Brachetto',
#  'Braucol',
#  'Bual',
#  'Canaiolo',
#  'Cannonau',
#  'Caprettone',
#  'Carcajolu',
#  'Carignan',
#  'Carignan-Grenache',
#  'Carignan-Syrah',
#  'Carignane',
#  'Carignano',
#  'Carineña',
#  'Cariñena-Garnacha',
#  'Carmenère',
#  'Carmenère-Syrah',
#  'Carricante',
#  'Casavecchia',
#  'Castelão',
#  'Catalanesca',
#  'Catarratto',
#  'Cayuga',
#  'Centesimino',
#  'Cerceal',
#  'Cercial',
#  'Cesanese',
#  "Cesanese d'Affile",
#  'Chambourcin',
#  'Champagne Blend',
#  'Chancellor',
#  'Charbono',
#  'Chardonel',
#  'Chardonnay',
#  'Chardonnay Weissburgunder',
#  'Chardonnay-Albariño',
#  'Chardonnay-Pinot Gris',
#  'Chardonnay-Riesling',
#  'Chardonnay-Sauvignon',
#  'Chardonnay-Semillon',
#  'Chardonnay-Viognier',
#  'Chasselas',
#  'Chelois',
#  'Chinuri',
#  'Ciliegiolo',
#  'Cinsault',
#  'Clairette',
#  'Claret',
#  'Cococciola',
#  'Coda di Volpe',
#  'Colombard',
#  'Colorino',
#  'Cortese',
#  'Corvina',
#  'Corvina, Rondinella, Molinara',
#  'Counoise',
#  'Códega do Larinho',
#  'Dafni',
#  'Debit',
#  'Diamond',
#  'Dolcetto',
#  'Dornfelder',
#  'Duras',
#  'Durella',
#  'Durif',
#  'Edelzwicker',
#  'Ekigaïna',
#  'Elbling',
#  'Emir',
#  'Encruzado',
#  'Erbaluce',
#  'Espadeiro',
#  'Falanghina',
#  'Favorita',
#  'Fer Servadou',
#  'Fernão Pires',
#  'Feteasca',
#  'Feteasca Neagra',
#  'Feteascǎ Regalǎ',
#  'Fiano',
#  'Forcallà',
#  'Francisa',
#  'Franconia',
#  'Frankovka',
#  'Frappato',
#  'Freisa',
#  'Friulano',
#  'Früburgunder',
#  'Furmint',
#  'G-S-M',
#  'Gaglioppo',
#  'Gamay',
#  'Gamza',
#  'Garganega',
#  'Garnacha',
#  'Garnacha Blend',
#  'Garnacha Tintorera',
#  'Garnacha-Cariñena',
#  'Garnacha-Monastrell',
#  'Garnacha-Syrah',
#  'Garnacha-Tempranillo',
#  'Gelber Muskateller',
#  'Gelber Traminer',
#  'Glera',
#  'Godello',
#  'Gouveio',
#  'Graciano',
#  'Gragnano',
#  'Grauburgunder',
#  'Graševina',
#  'Grecanico',
#  'Grechetto',
#  'Greco',
#  'Greco Bianco',
#  'Grenache',
#  'Grenache Blend',
#  'Grenache Gris',
#  'Grenache-Carignan',
#  'Grenache-Mourvèdre',
#  'Grenache-Shiraz',
#  'Grenache-Syrah',
#  'Grignolino',
#  'Grillo',
#  'Grolleau',
#  'Groppello',
#  'Gros Manseng',
#  'Gros Plant',
#  'Gros and Petit Manseng',
#  'Grüner Veltliner',
#  'Hondarrabi Zuri',
#  'Hárslevelü',
#  'Incrocio Manzoni',
#  'Insolia',
#  'Inzolia',
#  'Irsai Oliver',
#  'Jacquez',
#  'Jacquère',
#  'Jaen',
#  'Jampal',
#  'Johannisberg Riesling',
#  'Kadarka',
#  'Kalecik Karasi',
#  'Kangoun',
#  'Karalahna',
#  'Karasakiz',
#  'Kekfrankos',
#  'Kerner',
#  'Kinali Yapincak',
#  'Kisi',
#  'Kotsifali',
#  'Kuntra',
#  'Lagrein',
#  'Lambrusco',
#  'Lambrusco Grasparossa',
#  'Lambrusco Salamino',
#  'Lambrusco di Sorbara',
#  'Lemberger',
#  'Listán Negro',
#  "Loin de l'Oeil",
#  'Loureiro',
#  'Loureiro-Arinto',
#  'Macabeo',
#  'Macabeo-Chardonnay',
#  'Macabeo-Moscatel',
#  'Madeira Blend',
#  'Madeleine Angevine',
#  'Magliocco',
#  'Malagousia',
#  'Malagouzia',
#  'Malagouzia-Chardonnay',
#  'Malvar',
#  'Malvasia',
#  'Malvasia Bianca',
#  'Malvasia Fina',
#  'Malvasia Istriana',
#  'Malvasia Nera',
#  'Malvasia di Candia',
#  'Malvasia-Viura',
#  'Mandilaria',
#  'Mansois',
#  'Mantonico',
#  'Manzoni',
#  'Marawi',
#  'Maria Gomes',
#  'Maria Gomes-Bical',
#  'Marquette',
#  'Marsanne',
#  'Marsanne-Roussanne',
#  'Marsanne-Viognier',
#  'Marselan',
#  'Marzemino',
#  'Mataro',
#  'Maturana',
#  'Mauzac',
#  'Mavrodaphne',
#  'Mavrokalavryta',
#  'Mavrotragano',
#  'Mavroudi',
#  'Mavrud',
#  'Mazuelo',
#  'Melnik',
#  'Melon',
#  'Mencía',
#  'Meritage',
#  'Merlot',
#  'Merlot-Argaman',
#  'Merlot-Grenache',
#  'Merlot-Petite Verdot',
#  'Merlot-Shiraz',
#  'Merlot-Syrah',
#  'Merlot-Tannat',
#  'Meseguera',
#  'Misket',
#  'Mission',
#  'Molinara',
#  'Monastrell',
#  'Monastrell-Petit Verdot',
#  'Monastrell-Syrah',
#  'Mondeuse',
#  'Monica',
#  'Montepulciano',
#  'Morava',
#  'Morillon',
#  'Morio Muskat',
#  'Moscadello',
#  'Moscatel',
#  'Moscatel Graúdo',
#  'Moscatel Roxo',
#  'Moscatel de Alejandría',
#  'Moscato',
#  'Moscato Giallo',
#  'Moscato Rosa',
#  'Moscato di Noto',
#  'Moschofilero',
#  'Moschofilero-Chardonnay',
#  'Mourvèdre',
#  'Mourvèdre-Syrah',
#  'Mtsvane',
#  'Muscadel',
#  'Muscadelle',
#  'Muscadine',
#  'Muscat',
#  'Muscat Canelli',
#  'Muscat Hamburg',
#  "Muscat d'Alexandrie",
#  'Muscat of Alexandria',
#  'Muscatel',
#  'Muskat',
#  'Muskat Ottonel',
#  'Muskateller',
#  'Müller-Thurgau',
#  'Narince',
#  'Nascetta',
#  'Nasco',
#  'Nebbiolo',
#  'Negrette',
#  'Negroamaro',
#  'Nerello Cappuccio',
#  'Nerello Mascalese',
#  "Nero d'Avola",
#  'Nero di Troia',
#  'Neuburger',
#  'Nielluciu',
#  'Norton',
#  'Nosiola',
#  'Nuragus',
#  'Ojaleshi',
#  'Okuzgozu',
#  'Ondenc',
#  'Orange Muscat',
#  'Orangetraube',
#  'Other',
#  'Otskhanuri Sapere',
#  'Pallagrello',
#  'Pallagrello Bianco',
#  'Pallagrello Nero',
#  'Palomino',
#  'Papaskarasi',
#  'Paralleda',
#  'Parraleta',
#  'Passerina',
#  'País',
#  'Pecorino',
#  'Pedro Ximénez',
#  'Perricone',
#  'Petit Courbu',
#  'Petit Manseng',
#  'Petit Meslier',
#  'Petit Verdot',
#  'Petite Sirah',
#  'Petite Verdot',
#  'Picapoll',
#  'Picolit',
#  'Picpoul',
#  'Piedirosso',
#  'Pigato',
#  'Pignoletto',
#  'Pignolo',
#  'Pinot Auxerrois',
#  'Pinot Bianco',
#  'Pinot Grigio',
#  'Pinot Gris',
#  'Pinot Meunier',
#  'Pinot Nero',
#  'Pinot-Chardonnay',
#  'Pinotage',
#  'Pinotage-Merlot',
#  'Plavac Mali',
#  'Plyto',
#  'Port',
#  'Portuguiser',
#  'Posip',
#  'Poulsard',
#  'Premsal',
#  'Prieto Picudo',
#  'Primitivo',
#  'Prosecco',
#  'Prugnolo Gentile',
#  'Prunelard',
#  'Pugnitello',
#  'Rabigato',
#  'Raboso',
#  'Ramisco',
#  'Rara Neagra',
#  'Rebo',
#  'Rebula',
#  'Refosco',
#  'Ribolla Gialla',
#  'Rieslaner',
#  'Riesling',
#  'Riesling-Chardonnay',
#  'Rivaner',
#  'Rkatsiteli',
#  'Robola',
#  'Roditis',
#  'Roditis-Moschofilero',
#  'Rolle',
#  'Romorantin',
#  'Rosado',
#  'Rosato',
#  'Roscetto',
#  'Rosenmuskateller',
#  'Roter Traminer',
#  'Roter Veltliner',
#  'Rotgipfler',
#  'Roussanne',
#  'Roussanne-Marsanne',
#  'Roussanne-Viognier',
#  'Roviello',
#  'Ruché',
#  'Rufete',
#  'Ryzlink Rýnský',
#  'Sacy',
#  'Sagrantino',
#  'Sangiovese',
#  'Sangiovese Grosso',
#  'Sangiovese-Syrah',
#  'Saperavi',
#  'Saperavi-Merlot',
#  'Sauvignon',
#  'Sauvignon Gris',
#  'Sauvignon Musqué',
#  'Sauvignon-Sémillon',
#  'Sauvignonasse',
#  'Savagnin',
#  'Savatiano',
#  'Scheurebe',
#  'Schiava',
#  'Schwartzriesling',
#  'Sciaccerellu',
#  'Semillon-Chardonnay',
#  'Sercial',
#  'Sherry',
#  'Shiraz',
#  'Shiraz-Grenache',
#  'Shiraz-Mourvèdre',
#  'Shiraz-Roussanne',
#  'Shiraz-Tempranillo',
#  'Shiraz-Viognier',
#  'Sideritis',
#  'Siegerrebe',
#  'Silvaner',
#  'Silvaner-Traminer',
#  'Siria',
#  'Sirica',
#  'Sousão',
#  'Souzao',
#  'Spätburgunder',
#  'St. Laurent',
#  'St. Vincent',
#  'Susumaniello',
#  'Sylvaner',
#  'Symphony',
#  'Syrah',
#  'Syrah-Bonarda',
#  'Syrah-Carignan',
#  'Syrah-Grenache',
#  'Syrah-Grenache-Viognier',
#  'Syrah-Merlot',
#  'Syrah-Mourvèdre',
#  'Syrah-Petit Verdot',
#  'Syrah-Petite Sirah',
#  'Syrah-Tempranillo',
#  'Syrah-Viognier',
#  'Sämling',
#  'Sémillon',
#  'Tamianka',
#  'Tamjanika',
#  'Tannat',
#  'Tannat-Merlot',
#  'Tannat-Syrah',
#  'Tempranillo',
#  'Tempranillo Blend',
#  'Tempranillo-Garnacha',
#  'Tempranillo-Merlot',
#  'Tempranillo-Shiraz',
#  'Tempranillo-Syrah',
#  'Tempranillo-Tannat',
#  'Teran',
#  'Teroldego',
#  'Teroldego Rotaliano',
#  'Terrantez',
#  'Thrapsathiri',
#  'Timorasso',
#  'Tinta Amarela',
#  'Tinta Barroca',
#  'Tinta Cao',
#  'Tinta Fina',
#  'Tinta Francisca',
#  'Tinta Madeira',
#  'Tinta Miúda',
#  'Tinta Negra Mole',
#  'Tinta Roriz',
#  'Tinta de Toro',
#  'Tinta del Pais',
#  'Tinta del Toro',
#  'Tintilia ',
#  'Tinto Fino',
#  'Tinto Velasco',
#  'Tinto del Pais',
#  'Tocai',
#  'Tocai Friulano',
#  'Tokaji',
#  'Tokay',
#  'Tokay Pinot Gris',
#  'Torbato',
#  'Torontel',
#  'Torrontés',
#  'Touriga',
#  'Touriga Franca',
#  'Touriga Nacional',
#  'Touriga Nacional Blend',
#  'Trajadura',
#  'Traminer',
#  'Traminette',
#  'Trebbiano',
#  'Trebbiano Spoletino',
#  'Trebbiano di Lugana',
#  'Treixadura',
#  'Trepat',
#  'Trincadeira',
#  'Trollinger',
#  'Trousseau',
#  'Trousseau Gris',
#  'Tsapournakos',
#  'Tsolikouri',
#  'Turbiana',
#  'Tămâioasă Românească',
#  'Uva di Troia',
#  'Uvalino',
#  'Valdiguié',
#  'Valvin Muscat',
#  'Veltliner',
#  'Verdeca',
#  'Verdejo',
#  'Verdejo-Viura',
#  'Verdelho',
#  'Verdicchio',
#  'Verdil',
#  'Verdosilla',
#  'Verduzzo',
#  'Verduzzo Friulano ',
#  'Vermentino',
#  'Vermentino Nero',
#  'Vernaccia',
#  'Vespaiolo',
#  'Vespolina',
#  'Vidadillo',
#  'Vidal',
#  'Vignoles',
#  'Vilana',
#  'Vinhão',
#  'Viognier',
#  'Viognier-Chardonnay',
#  'Viognier-Marsanne',
#  'Viognier-Roussanne',
#  'Viognier-Valdiguié',
#  'Viosinho',
#  'Vital',
#  'Vitovska',
#  'Viura',
#  'Viura-Chardonnay',
#  'Viura-Verdejo',
#  'Vranac',
#  'Vranec',
#  'Weissburgunder',
#  'Welschriesling',
#  'Xarel-lo',
#  'Xinisteri',
#  'Xinomavro',
#  'Xynisteri',
#  'Yapincak',
#  'Zelen',
#  'Zibibbo',
#  'Zierfandler',
#  'Zierfandler-Rotgipfler',
#  'Zinfandel',
#  'Zlahtina',
#  'Zweigelt',
#  'nan',
#  'Çalkarası',
#  'Žilavka']
